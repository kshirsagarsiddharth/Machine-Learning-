# %%
import pandas as pd
import numpy as np
import nltk
import re
import pprint
from bs4 import BeautifulSoup
from urllib import request
from nltk.corpus import wordnet as wn
from operator import itemgetter
from timeit import Timer

# %% [markdown]
# Question 1

# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(...)
#  |      S.__format__(format_spec) -> str
#  |
#  |      Return a formatted version of S as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...

# %%
help(list)
# Out:
# Help on class list in module builtins:
#
# class list(object)
#  |  list() -> new empty list
#  |  list(iterable) -> new list initialized from iterable's items
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
# ...

# %%
help(dict)
# Out:
# Help on class dict in module builtins:
#
# class dict(object)
#  |  dict() -> new empty dictionary
#  |  dict(mapping) -> new dictionary initialized from a mapping object's
#  |      (key, value) pairs
#  |  dict(iterable) -> new dictionary initialized as if via:
#  |      d = {}
#  |      for k, v in iterable:
#  |          d[k] = v
#  |  dict(**kwargs) -> new dictionary initialized with the name=value pairs
#  |      in the keyword argument list.  For example:  dict(one=1, two=2)
#  |
#  |  Methods defined here:
#  |
#  |  __contains__(self, key, /)
#  |      True if D has a key k, else False.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
# ...

# %%
help(tuple)
# Out:
# Help on class tuple in module builtins:
#
# class tuple(object)
#  |  tuple() -> empty tuple
#  |  tuple(iterable) -> tuple initialized from iterable's items
#  |
#  |  If the argument is a tuple, the return value is the same object.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, key, /)
#  |      Return self[key].
#  |
#  |  __getnewargs__(...)
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __hash__(self, /)
#  |      Return hash(self).
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __len__(self, /)
# ...

# %% [markdown]
# Question 2

# %%
exp_list = ['natural','language','processing']
exp_tuple = 'natural','language','processing'
print('language' in exp_list)
print('languagr' in exp_tuple)
print(exp_list[0])
print(exp_tuple[1:])
print(len(exp_list))
print(len(exp_tuple))
print(min(exp_list))
print(min(exp_tuple))
print(exp_list.index('language'))
print(exp_tuple.index('processing',1))
# Out:
# True
# False
# natural
# ('language', 'processing')
# 3
# 3
# language
# language
# 1
# 2

# %% [markdown]
# Question 3

# %%
tuple1 = 'single'
tuple2 = tuple(['single'])

# %% [markdown]
# Question 4

# %%
word = ['is','nlp','fun','?']
word[0],word[1] = word[1],word[0]
word[-1] ='!'
word
# Out:
# ['nlp', 'is', 'fun', '!']

# %%
word_tuple = 'is','nlp','fun','?'
word = word_tuple[1],word_tuple[0],word_tuple[2],'!'
list(word)
# Out:
# ['nlp', 'is', 'fun', '!']

# %% [markdown]
# Question 6

# %%
sent = 'the dog dave john the newspaper'.split()
n  = len(sent)
[sent[i:i+n] for i in range(len(sent)-n+1)]
# Out:
# [['the', 'dog', 'dave', 'john', 'the', 'newspaper']]

# %% [markdown]
# Question 7

# %%
a = 1
if a:
    print('true')
else:
    print('false')
# Out:
# true

# %% [markdown]
# Question 8

# %%
print('monty' < 'python')
print('Z' < 'a')
print('Monty' < 'Montague')
# Out:
# True
# True
# False

# %% [markdown]
# Question 9

# %%
sent = ' this is \n a sample\t sentence   with lot of \t\t tabs and \n next line commands \n. '
' '.join(sent.split())
# Out:
# 'this is a sample sentence with lot of tabs and next line commands .'

# %%
sent2 = re.sub(r'^\s|\s$','',sent) # removing spaces at starting and ending of words
re.sub(r'\s+',' ',sent2) #removing spaces in between the sentences
# Out:
# 'this is a sample sentence with lot of tabs and next line commands .'

# %% [markdown]
# Question 10

# %%
text = 'a program to sort words by their length'.split()
sorted(text,key=len,reverse = True)
# Out:
# ['program', 'length', 'words', 'their', 'sort', 'to', 'by', 'a']

# %% [markdown]
# Question 11

# %%
sent1 = ['a','list','of','words']
sent2 = sent1
sent1[2] = 'yut'
sent2
# yes sent 2 changes because we are dealing directly with pointers
# Out:
# ['a', 'list', 'yut', 'words']

# %%
sent1 = ['a','list','of','words']
sent2 = sent1[:] # in this case copy is made of the values so there is no affect of modification
sent1[2] = 'yut'
sent2
# Out:
# ['a', 'list', 'of', 'words']

# %%
from copy import deepcopy
help(deepcopy)
# Out:
# Help on function deepcopy in module copy:
#
# deepcopy(x, memo=None, _nil=[])
#     Deep copy operation on arbitrary Python objects.
#
#     See the module's __doc__ string for more info.

# %%
text1 = [['The', 'dog', 'gave', 'John', 'the', 'newspaper'], ['The', 'cat', 'miowed']]
text2 = deepcopy(text1)
text1[1][1] = 'going'

# %% [markdown]
# Question 12

# %%
m = 4
n = 3
word_table = [['']*n]*m
word_table[1][2] = 'hello'

# %%
word_table
# Out:
# [['', '', 'hello'], ['', '', 'hello'], ['', '', 'hello'], ['', '', 'hello']]

# %%
word_table = [['' for _ in range(n)] for _ in range(m)]

# %%
word_table[1][2] = 'hello'

# %%
word_table
# Out:
# [['', '', ''], ['', '', 'hello'], ['', '', ''], ['', '', '']]

# %% [markdown]
# Question 13

# %%
n = 10
word_vovels = [[set() for _ in range(n)] for _ in range(n)]
word_list ='lets write a ptyhon program through which we can we can initalize a array and process it'.split()
for word in word_list:
    l = len(word)
    v = sum(len(letter) for letter in word if letter in 'aeiou')
    if l < n:
        word_vovels[l][v].add(word)

# %%
n = 10
set_matrix = [[set() for _ in range(n)] for _ in range(10)]
word_list ='''"In order for a class to define its own copy implementation, it can define special methods __copy__() and __deepcopy__(). The former is called to implement the shallow copy operation; no additional arguments are passed. The latter is called to implement the deep copy operation; it is passed one argument, the memo dictionary. If the __deepcopy__() implementation needs to make a deep copy of a component, it should call the deepcopy() function with the component as first argument and the memo dictionary as second argument."'''.split()
for word in word_list:
    l = len(word)
    v = sum(len(letter) for letter in word if letter in 'aeiou')
    if l < n:
        set_matrix[l][v].add(word)

# %%
set_matrix
# Out:
# [[set(), set(), set(), set(), set(), set(), set(), set(), set(), set()],
#  [set(), {'a'}, set(), set(), set(), set(), set(), set(), set(), set()],
#  [{'If'},
#   {'as', 'is', 'it', 'no', 'of', 'to'},
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set()],
#  [{'"In'},
#   {'The', 'and', 'can', 'for', 'its', 'own', 'the'},
#   {'are', 'one'},
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set()],
#  [set(),
#   {'call', 'copy', 'with'},
#   {'deep', 'make', 'memo'},
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set()],
#  [set(),
#   {'class', 'first'},
#   {'needs', 'order'},
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set()],
#  [set(),
#   set(),
#   {'called', 'former', 'latter', 'passed', 'second', 'should'},
#   {'define'},
#   set(),
#   set(),
#   set(),
#   set(),
#   set(),
#   set()],
#  [set(),
#   set(),
#   {'methods', 'passed.', 'shallow'},
#   {'special'},
# ...

# %% [markdown]
# Question 10

# %%
text_list = text1
text_len = len(text1)
ans = {word for word in text_list[int(text_len * 0.9):] if word not in text_list[:int(text_len * 0.9)]}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-d00e04670d09> in <module>
#       1 text_list = text1
#       2 text_len = len(text1)
# ----> 3 ans = {word for word in text_list[int(text_len * 0.9):] if word not in text_list[:int(text_len * 0.9)]}
#
# <ipython-input-28-d00e04670d09> in <setcomp>(.0)
#       1 text_list = text1
#       2 text_len = len(text1)
# ----> 3 ans = {word for word in text_list[int(text_len * 0.9):] if word not in text_list[:int(text_len * 0.9)]}
#
# TypeError: unhashable type: 'list'

# %%
def novel10(text):
    text_len = len(text)
    ans = {word for word in text_list[int(text_len * 0.9):] if word not in text_list[:int(text_len * 0.9)]}
    return ans

# %%
from nltk.book import *
#novel10(text3)
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %% [markdown]
# Question 15

# %%
sent = "print"
fd = nltk.FreqDist(sent)
for key in sorted(fd.keys()):
    print(key,fd[key])
# Out:
# i 1
# n 1
# p 1
# r 1
# t 1

# %% [markdown]
# Question 16

# %%
word = 'siddharth'
letter_vals = {'a':1, 'b':2, 'c':3, 'd':4, 'e':5, 'f':80, 'g':3, 'h':8, 'i':10, 'j':10, 'k':20, 'l':30,
               'm':40, 'n':50, 'o':70, 'p':80, 'q':100, 'r':200, 's':300, 't':400, 'u':6, 'v':6, 'w':800, 
               'x':60, 'y':10, 'z':7}
#sum(l for l in letter_val )

# %%
sum(letter_vals[l] for l in word if len(re.findall(r'[a-z]',l)) > 0)
# Out:
# 935

# %%
def gematic(word):
    letter_vals = {'a':1, 'b':2, 'c':3, 'd':4, 'e':5, 'f':80, 'g':3, 'h':8, 'i':10, 'j':10, 'k':20, 'l':30,
               'm':40, 'n':50, 'o':70, 'p':80, 'q':100, 'r':200, 's':300, 't':400, 'u':6, 'v':6, 'w':800, 
               'x':60, 'y':10, 'z':7}
    return sum(letter_vals[l] for l in word if len(re.findall(r'[a-z]',l)) > 0)

# %%
gematic('savetheprogram')
# Out:
# 1319

# %%
files = nltk.corpus.state_union.fileids()
nltk.corpus.state_union.words()
[(fileid,word) for fileid in files for word in nltk.corpus.state_union.words(fileid) if word.isalpha() and gematic(word.lower()) == 666 ][:7]
# Out:
# [('1945-Truman.txt', 'eloquent'),
#  ('1945-Truman.txt', 'outlook'),
#  ('1946-Truman.txt', 'OUTLOOK'),
#  ('1946-Truman.txt', 'outlook'),
#  ('1946-Truman.txt', 'outlook'),
#  ('1946-Truman.txt', 'market'),
#  ('1946-Truman.txt', 'market')]

# %%
from random import randint
from nltk.book import *
def gematic(words):
    letter_vals = {'a':1, 'b':2, 'c':3, 'd':4, 'e':5, 'f':80, 'g':3, 'h':8, 'i':10, 'j':10, 'k':20, 'l':30,
               'm':40, 'n':50, 'o':70, 'p':80, 'q':100, 'r':200, 's':300, 't':400, 'u':6, 'v':6, 'w':800, 
               'x':60, 'y':10, 'z':7}
    return sum(letter_vals[letter] for letter in words if len(re.findall(r'[a-z]',letter)) > 0)
num = randint(1,1000)
set(word for word in text3 if word.isalpha() and gematic(word.lower()) == num)
# Out:
# {'gro'}

# %%
def decode(text):
    num = randint(1,1000)
    return num,set(words for words in text if words.isalpha() and  gematic(words.lower()) == num)

# %%
decode(text2)
# Out:
# (194, {'couple'})

# %% [markdown]
# Question 17

# %%
from nltk import FreqDist
def shorted(text,n):
    fd = FreqDist(text).most_common(n)
    most_freq_words = [words for (words,num) in fd]
    return [words for words in text if words not in most_freq_words][:10]

# %%
shorted(text2,2400)
# Out:
# ['[',
#  'Sense',
#  'Sensibility',
#  'Jane',
#  'Austen',
#  '1811',
#  ']',
#  '1',
#  'centre',
#  'generations']

# %% [markdown]
# Question 18

# %%
dicto = nltk.corpus.cmudict.entries()

# %%
df = pd.DataFrame(dicto)
#df.head()
df[1] = df[1].apply(lambda x : ','.join(x))
df.columns = ['key','value']
def get_word(syllable):
    return df[df['value'] == syllable]['key']

# %% [markdown]
# Question 19

# %%
#minke_whale.n.01, orca.n.01, novel.n.01 ,tortoise.n.01 , sort them according to their shortest_path_distance() from right_whale.n.01 .
from nltk.corpus import wordnet as wn
list_wn = [wn.synset('minke_whale.n.01'),wn.synset('orca.n.01'),wn.synset('novel.n.01'),wn.synset('tortoise.n.01')]
sorted(list_wn,key = lambda x : wn.synset('tortoise.n.01').shortest_path_distance(x) )
# Out:
# [Synset('tortoise.n.01'),
#  Synset('lesser_rorqual.n.01'),
#  Synset('killer_whale.n.01'),
#  Synset('novel.n.01')]

# %% [markdown]
# Question 21

# %%
def diff(text,vocab):
    return set(text).difference(vocab)

# %%
diff('hello my name is siddharth'.split(),'my name is'.split())
# Out:
# {'hello', 'siddharth'}

# %% [markdown]
# Question 22

# %%
from operator import itemgetter
print(itemgetter('name')({'name':'tu','age':19}))
# Out:
# 'tu'

# %%
inventory = [('apple',3),('banana',2),('pear',5),('orange',1)]
getcount = itemgetter(1)
print(list(map(getcount,inventory)))
print(sorted(inventory,key = getcount))
# Out:
# [3, 2, 5, 1]
# [('orange', 1), ('banana', 2), ('apple', 3), ('pear', 5)]

# %%
text = 'htions fall into categories that perform object comparisons'.split()
sorted(text,key = itemgetter(1))
# Out:
# ['fall',
#  'categories',
#  'object',
#  'perform',
#  'that',
#  'into',
#  'comparisons',
#  'htions']

# %% [markdown]
# Question 23

# %%
import pprint
def insert(trie,key,value):
    if key:
        first,rest = key[0],key[1:]
        if first not in trie:
            trie[first] = {}
        insert(trie[first],rest,value)
    else:
        trie['value'] = value

# %%
trie = {}
insert(trie, 'chat', 'cat')
insert(trie, 'chien', 'dog')
insert(trie, 'chair', 'flesh')
insert(trie, 'chic', 'stylish')
pprint.pprint(trie, width=40)
# Out:
# {'c': {'h': {'a': {'i': {'r': {'value': 'flesh'}},
#                    't': {'value': 'cat'}},
#              'i': {'c': {'value': 'stylish'},
#                    'e': {'n': {'value': 'dog'}}}}}}

# %% [markdown]
# Question 26

# %%
def catalan_recursive(n):
    if n == 0 or n == 1:
        return 1
    else:
        c = 0
        for i in range(n):
            c += catalan_recursive(i) * catalan_recursive(i - 1)
        return c
