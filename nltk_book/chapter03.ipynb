# %%
import nltk
import re
import urllib
import pandas as pd
from nltk import word_tokenize

# %%
from urllib import request
url = "http://www.gutenberg.org/files/2554/2554-0.txt"
response = request.urlopen(url)
raw = response.read().decode('utf8')

# %%
tokens = word_tokenize(raw)
len(tokens)
# Out:
# 257727

# %%
tokens[:10]
# Out:
# ['\ufeffThe',
#  'Project',
#  'Gutenberg',
#  'EBook',
#  'of',
#  'Crime',
#  'and',
#  'Punishment',
#  ',',
#  'by']

# %%
text = nltk.Text(tokens)

# %%
type(text)
# Out:
# nltk.text.Text

# %%
raw.find('PART I')
# Out:
# 5336

# %%
raw.rfind('End of Project Gutenberg’s Crime')
# Out:
# 1157812

# %%
from urllib import request
url = "http://www.gutenberg.org/files/2554/2554-0.txt"
response = request.urlopen(url)
raw = response.read().decode('utf8')
# in this case we want only the text 
raw = raw[5336:1157812]
raw.find('PART I')
# Out:
# 0

# %%
from urllib import request
url = "http://news.bbc.co.uk/2/hi/health/2284783.stm"
response = request.urlopen(url).read().decode('utf8')
response[:60]
# Out:
# '<!doctype html public "-//W3C//DTD HTML 4.0 Transitional//EN'

# %%
from urllib import request
url = "http://news.bbc.co.uk/2/hi/health/2284783.stm"
response = request.urlopen(url).read().decode('utf8')
response[:60]
from bs4 import BeautifulSoup
raw = BeautifulSoup(response,'html.parser').get_text()
tokens = word_tokenize(raw)
tokens = tokens[110:390]
text = nltk.Text(tokens)
text
# Out:
# <Text: UK Blondes 'to die out in 200 years'...>

# %%
text.concordance('gene')
# Out:
# Displaying 5 of 5 matches:
# hey say too few people now carry the gene for blondes to last beyond the next
# blonde hair is caused by a recessive gene . In order for a child to have blond
#  have blonde hair , it must have the gene on both sides of the family in the g
# ere is a disadvantage of having that gene or by chance . They do n't disappear
# des would disappear is if having the gene was a disadvantage and I do not thin

# %%
from urllib import request
from bs4 import BeautifulSoup
url = "http://news.bbc.co.uk/2/hi/health/2284783.stm"
response = request.urlopen(url).read().decode('utf8')
raw = BeautifulSoup(response,'html.parser').get_text()
tokens = word_tokenize(raw)

# %%
tokens = tokens[110:390]
text = nltk.Text(tokens)

# %%
text.concordance('gene')
# Out:
# Displaying 5 of 5 matches:
# hey say too few people now carry the gene for blondes to last beyond the next
# blonde hair is caused by a recessive gene . In order for a child to have blond
#  have blonde hair , it must have the gene on both sides of the family in the g
# ere is a disadvantage of having that gene or by chance . They do n't disappear
# des would disappear is if having the gene was a disadvantage and I do not thin

# %%
f = open('../input/sample.txt')

# %%
raw = f.read()

# %%
raw
# Out:
# "I would love to try or hear the sample audio your app can produce. I do not want to purchase, because I've purchased so many apps that say they do something and do not deliver.  \n\nCan you please add audio samples with text you've converted? I'd love to see the end results.\n\nThanks!"

# %%
import os
os.listdir('.')
# Out:
# ['.ipynb_checkpoints', '__notebook_source__.ipynb']

# %%
f.read()
# Out:
# ''

# %%
f = open('../input/sample.txt','rU')
for line in f:
    print(line.strip())
# Out:
# I would love to try or hear the sample audio your app can produce. I do not want to purchase, because I've purchased so many apps that say they do something and do not deliver.
#
# Can you please add audio samples with text you've converted? I'd love to see the end results.
#
# Thanks!
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: 'U' mode is deprecated
#   """Entry point for launching an IPython kernel.

# %%
path = nltk.data.find('corpora/gutenberg/melville-moby_dick.txt')
raw = open(path,'r').read()

# %%
s = input('Enter Some Text:')
print('You Typed',len(word_tokenize(s)),'words')
# Out:
# Enter Some Text:hello
# You Typed 1 words

# %%
raw = open('../input/sample.txt').read()
tokens = word_tokenize(raw)
words = [word.lower() for word in tokens]
vocab = sorted(set(words))

# %%
raw = open('../input/sample.txt').read()
tokens = word_tokenize(raw)
words = [word.lower() for word in tokens]
vocab = sorted(set(words))

# %%
vocab.append('blog')

# %%
monty = 'Monty Python'
monty
# Out:
# 'Monty Python'

# %%
circus = 'Monty Python\'s Flying Circus'
circus
# Out:
# "Monty Python's Flying Circus"

# %%
>>> a = [1, 2, 3, 4, 5, 6, 7, 6, 5, 4, 3, 2, 1]
>>> b = [' ' * 2 * (7 - i) + 'very' * i for i in a]
>>> for line in b:
...     print(line)
# Out:
#             very
#           veryvery
#         veryveryvery
#       veryveryveryvery
#     veryveryveryveryvery
#   veryveryveryveryveryvery
# veryveryveryveryveryveryvery
#   veryveryveryveryveryvery
#     veryveryveryveryvery
#       veryveryveryvery
#         veryveryvery
#           veryvery
#             very

# %%
sent = 'colorless green ideas sleep furiously'
for char in sent:
    print(char,end = ' ')
# Out:
# c o l o r l e s s   g r e e n   i d e a s   s l e e p   f u r i o u s l y

# %%
from nltk.corpus import gutenberg
raw = gutenberg.raw('melville-moby_dick.txt')
fdist = nltk.FreqDist(ch.lower() for ch in raw if ch.isalpha())

# %%
fdist
# Out:
# FreqDist({'e': 117092, 't': 87996, 'a': 77916, 'o': 69326, 'n': 65617, 'i': 65434, 's': 64231, 'h': 62896, 'r': 52134, 'l': 42793, ...})

# %%
path = nltk.data.find('corpora/unicode_samples/polish-lat2.txt')

# %%
f = open(path,encoding = 'latin2')
for line in f:
    print(line.strip())
# Out:
# Pruska Biblioteka Państwowa. Jej dawne zbiory znane pod nazwą
# "Berlinka" to skarb kultury i sztuki niemieckiej. Przewiezione przez
# Niemców pod koniec II wojny światowej na Dolny Śląsk, zostały
# odnalezione po 1945 r. na terytorium Polski. Trafiły do Biblioteki
# Jagiellońskiej w Krakowie, obejmują ponad 500 tys. zabytkowych
# archiwaliów, m.in. manuskrypty Goethego, Mozarta, Beethovena, Bacha.

# %%
f = open(path,encoding='latin2')
for line in f:
    line = line.strip()
    print(line.encode('unicode_escape'))
# Out:
# b'Pruska Biblioteka Pa\\u0144stwowa. Jej dawne zbiory znane pod nazw\\u0105'
# b'"Berlinka" to skarb kultury i sztuki niemieckiej. Przewiezione przez'
# b'Niemc\\xf3w pod koniec II wojny \\u015bwiatowej na Dolny \\u015al\\u0105sk, zosta\\u0142y'
# b'odnalezione po 1945 r. na terytorium Polski. Trafi\\u0142y do Biblioteki'
# b'Jagiello\\u0144skiej w Krakowie, obejmuj\\u0105 ponad 500 tys. zabytkowych'
# b'archiwali\\xf3w, m.in. manuskrypty Goethego, Mozarta, Beethovena, Bacha.'

# %%
import unicodedata
lines = open(path,encoding = 'latin2').readlines()
line = lines[2]
for c in line:
    if ord(c) > 127:
         print(c.encode('utf8'),ord(c),unicodedata.name(c))
# Out:
# b'\xc3\xb3' 243 LATIN SMALL LETTER O WITH ACUTE
# b'\xc5\x9b' 347 LATIN SMALL LETTER S WITH ACUTE
# b'\xc5\x9a' 346 LATIN CAPITAL LETTER S WITH ACUTE
# b'\xc4\x85' 261 LATIN SMALL LETTER A WITH OGONEK
# b'\xc5\x82' 322 LATIN SMALL LETTER L WITH STROKE

# %%
line.find('zosta\u0142y')
# Out:
# 54

# %%
line = line.lower()

# %%
line.encode('unicode_escape')
# Out:
# b'niemc\\xf3w pod koniec ii wojny \\u015bwiatowej na dolny \\u015bl\\u0105sk, zosta\\u0142y\\n'

# %%
import re
m = re.search('\u015b\w*',line)

# %%
m.group()
# Out:
# 'światowej'

# %%
word_tokenize(line)
# Out:
# ['niemców',
#  'pod',
#  'koniec',
#  'ii',
#  'wojny',
#  'światowej',
#  'na',
#  'dolny',
#  'śląsk',
#  ',',
#  'zostały']

# %%
wordlist = [word for word in nltk.corpus.words.words('en') if word.islower()]

# %%
[w for w in wordlist if re.search('ed$',w)] #find the words in the wordlist which end with ed
# Out:
# ['abaissed',
#  'abandoned',
#  'abased',
#  'abashed',
#  'abatised',
#  'abed',
#  'aborted',
#  'abridged',
#  'abscessed',
#  'absconded',
#  'absorbed',
#  'abstracted',
#  'abstricted',
#  'accelerated',
#  'accepted',
#  'accidented',
#  'accoladed',
#  'accolated',
#  'accomplished',
#  'accosted',
#  'accredited',
#  'accursed',
#  'accused',
#  'accustomed',
#  'acetated',
#  'acheweed',
#  'aciculated',
#  'aciliated',
#  'acknowledged',
#  'acorned',
#  'acquainted',
#  'acquired',
#  'acquisited',
#  'acred',
#  'aculeated',
#  'addebted',
#  'added',
#  'addicted',
#  'addlebrained',
#  'addleheaded',
#  'addlepated',
#  'addorsed',
#  'adempted',
#  'adfected',
#  'adjoined',
#  'admired',
#  'admitted',
#  'adnexed',
#  'adopted',
#  'adossed',
#  'adreamed',
#  'adscripted',
#  'aduncated',
#  'advanced',
#  'advised',
#  'aeried',
#  'aethered',
#  'afeared',
#  'affected',
#  'affectioned',
#  'affined',
#  'afflicted',
#  'affricated',
#  'affrighted',
# ...

# %%
[w for w in wordlist if re.search('^..j..t..$',w)]
# Out:
# ['abjectly',
#  'adjuster',
#  'dejected',
#  'dejectly',
#  'injector',
#  'majestic',
#  'objectee',
#  'objector',
#  'rejecter',
#  'rejector',
#  'unjilted',
#  'unjolted',
#  'unjustly']

# %%
[w for w in wordlist if re.search('^..j..t..$',w)]
# Out:
# ['abjectly',
#  'adjuster',
#  'dejected',
#  'dejectly',
#  'injector',
#  'majestic',
#  'objectee',
#  'objector',
#  'rejecter',
#  'rejector',
#  'unjilted',
#  'unjolted',
#  'unjustly']

# %%
[w for w in wordlist if re.search('^[ghi][mno][jlk][def]$',w)] # words formed my combination of the words in the square brackets
# Out:
# ['gold', 'golf', 'hold', 'hole']

# %%
[w for w in wordlist if re.search('^[g-o]+$',w)]
# Out:
# ['g',
#  'ghoom',
#  'gig',
#  'giggling',
#  'gigolo',
#  'gilim',
#  'gill',
#  'gilling',
#  'gilo',
#  'gim',
#  'gin',
#  'ging',
#  'gingili',
#  'gink',
#  'ginkgo',
#  'ginning',
#  'gio',
#  'glink',
#  'glom',
#  'glonoin',
#  'gloom',
#  'glooming',
#  'gnomon',
#  'go',
#  'gog',
#  'gogo',
#  'goi',
#  'going',
#  'gol',
#  'goli',
#  'gon',
#  'gong',
#  'gonion',
#  'goo',
#  'googol',
#  'gook',
#  'gool',
#  'goon',
#  'h',
#  'hi',
#  'high',
#  'hill',
#  'him',
#  'hin',
#  'hing',
#  'hinoki',
#  'ho',
#  'hog',
#  'hoggin',
#  'hogling',
#  'hoi',
#  'hoin',
#  'holing',
#  'holl',
#  'hollin',
#  'hollo',
#  'hollong',
#  'holm',
#  'homo',
#  'homologon',
#  'hong',
#  'honk',
#  'hook',
#  'hoon',
#  'i',
#  'igloo',
#  'ihi',
#  'ilk',
#  'ill',
#  'imi',
#  'imino',
#  'immi',
#  'in',
#  'ing',
#  'ingoing',
#  'inion',
#  'ink',
#  'inkling',
#  'inlook',
#  'inn',
#  'inning',
#  'io',
#  'ion',
#  'j',
#  'jhool',
#  'jig',
#  'jing',
#  'jingling',
# ...

# %%
[w for w in wordlist if re.search('^[a-fj-o]+$',w)]
# Out:
# ['a',
#  'aa',
#  'aal',
#  'aam',
#  'aba',
#  'abac',
#  'abaca',
#  'aback',
#  'abaff',
#  'abalone',
#  'abandon',
#  'abandonable',
#  'abandoned',
#  'abandonee',
#  'abb',
#  'abdal',
#  'abdomen',
#  'abeam',
#  'abed',
#  'abele',
#  'able',
#  'abloom',
#  'abode',
#  'abolla',
#  'aboma',
#  'aboon',
#  'academe',
#  'acana',
#  'acca',
#  'accede',
#  'accedence',
#  'accend',
#  'accolade',
#  'accoladed',
#  'accolle',
#  'accommodable',
#  'ace',
#  'ackman',
#  'acle',
#  'acme',
#  'acne',
#  'acnodal',
#  'acnode',
#  'acock',
#  'acold',
#  'acoma',
#  'acone',
#  'ad',
#  'adad',
#  'adance',
#  'add',
#  'adda',
#  'addable',
#  'added',
#  'addend',
#  'addenda',
#  'addle',
#  'ade',
#  'adead',
#  'adeem',
#  'adenocele',
#  'adenoma',
#  'adman',
#  'ado',
#  'adobe',
#  'ae',
#  'aefald',
#  'aenean',
#  'aeon',
#  'aface',
#  'affa',
#  'affable',
#  'aflame',
#  'afoam',
#  'ajaja',
#  'ak',
#  'aka',
#  'akala',
#  'ake',
#  'akeake',
#  'akee',
# ...

# %%
chat_words = sorted(set(w for w in nltk.corpus.nps_chat.words()))

# %%
[w for w in chat_words if re.search('^m+i+n+e+$',w)]
# Out:
# ['miiiiiiiiiiiiinnnnnnnnnnneeeeeeeeee',
#  'miiiiiinnnnnnnnnneeeeeeee',
#  'mine',
#  'mmmmmmmmiiiiiiiiinnnnnnnnneeeeeeee']

# %%
[w for w in chat_words if re.search('^[ha]+$',w)]
# Out:
# ['a',
#  'aaaaaaaaaaaaaaaaa',
#  'aaahhhh',
#  'ah',
#  'ahah',
#  'ahahah',
#  'ahh',
#  'ahhahahaha',
#  'ahhh',
#  'ahhhh',
#  'ahhhhhh',
#  'ahhhhhhhhhhhhhh',
#  'h',
#  'ha',
#  'haaa',
#  'hah',
#  'haha',
#  'hahaaa',
#  'hahah',
#  'hahaha',
#  'hahahaa',
#  'hahahah',
#  'hahahaha',
#  'hahahahaaa',
#  'hahahahahaha',
#  'hahahahahahaha',
#  'hahahahahahahahahahahahahahahaha',
#  'hahahhahah',
#  'hahhahahaha']

# %%
wsj = nltk.corpus.treebank.words()

# %%
[w for w in wsj if re.search('^[0-9]+\.[0-9]+$',w)] # finda all the decimal numbers in the corpora
# Out:
# ['9.8',
#  '8.45',
#  '8.47',
#  '8.04',
#  '7.90',
#  '1.5',
#  '352.7',
#  '9.37',
#  '9.45',
#  '8.12',
#  '8.14',
#  '8.19',
#  '8.22',
#  '8.53',
#  '8.56',
#  '83.4',
#  '2.80',
#  '2.87',
#  '3.1',
#  '5.29',
#  '0.7',
#  '5.39',
#  '50.45',
#  '50.38',
#  '7.5',
#  '3.2',
#  '7.3',
#  '2.6',
#  '2.29',
#  '2.25',
#  '2.2',
#  '4.8',
#  '5.5',
#  '3.75',
#  '1.55',
#  '737.5',
#  '3.01',
#  '38.375',
#  '12.5',
#  '2.5',
#  '3.1',
#  '72.7',
#  '0.4',
#  '2.875',
#  '98.3',
#  '4.75',
#  '19.3',
#  '5.9',
#  '20.5',
#  '38.3',
#  '10.2',
#  '37.3',
#  '1.5',
#  '16.125',
#  '13.73',
#  '37.5',
#  '9.625',
#  '2.4',
#  '1.82',
#  '84.29',
#  '150.00',
#  '2.2',
#  '86.12',
#  '47.6',
#  '236.74',
#  '236.79',
#  '59.6',
#  '2.1',
#  '415.6',
#  '415.8',
#  '0.1',
#  '0.3',
#  '109.73',
#  '0.9',
#  '0.2',
#  '127.03',
#  '3.9',
#  '0.1',
#  '1.6',
#  '234.4',
#  '5.4',
#  '0.5',
#  '497.34',
#  '0.3',
#  '0.9',
#  '191.9',
#  '2.6',
#  '99.1',
#  '4.3',
#  '18.95',
#  '17.95',
# ...

# %%
[w for w in wsj if re.search('^[A-Z]+\$$',w)] #find all the words in the corpus that ends with a dollar symbol
# Out:
# ['US$', 'C$', 'US$', 'C$', 'US$', 'US$']

# %%
[w for w in wsj if re.search('^[0-9]{4}$',w)] #find all four digit numbers
# Out:
# ['1956',
#  '1956',
#  '1953',
#  '1955',
#  '1997',
#  '1986',
#  '1990',
#  '1990',
#  '1990',
#  '1990',
#  '1989',
#  '1989',
#  '1990',
#  '1989',
#  '1989',
#  '1986',
#  '1989',
#  '1988',
#  '1985',
#  '1985',
#  '1986',
#  '1988',
#  '1991',
#  '1989',
#  '1990',
#  '1988',
#  '1977',
#  '1977',
#  '1977',
#  '1975',
#  '1981',
#  '1981',
#  '1990',
#  '1987',
#  '1988',
#  '1990',
#  '1988',
#  '1929',
#  '1987',
#  '1987',
#  '1992',
#  '1917',
#  '1934',
#  '1987',
#  '1987',
#  '1979',
#  '1977',
#  '1901',
#  '1988',
#  '1972',
#  '1999',
#  '1990',
#  '1976',
#  '1989',
#  '1988',
#  '1989',
#  '1983',
#  '1966',
#  '1987',
#  '1988',
#  '1987',
#  '1984',
#  '1986',
#  '1985',
#  '1987',
#  '1988',
#  '1979',
#  '1985',
#  '1988',
#  '1987',
#  '1985',
#  '1990',
#  '1984',
#  '8300',
#  '1985',
#  '1985',
#  '1985',
#  '8300',
#  '1988',
#  '1988',
#  '1986',
#  '1987',
#  '1987',
#  '1990',
#  '1984',
#  '1991',
#  '1990',
#  '1990',
#  '1991',
#  '1992',
# ...

# %%
[w for w in wsj if re.search('^[0-9]+-[a-z]{3,5}$',w)] # find number dash than a word
# Out:
# ['30-day',
#  '30-day',
#  '10-lap',
#  '52-week',
#  '50-state',
#  '14-hour',
#  '69-point',
#  '10-year',
#  '10-year',
#  '30-year',
#  '36-day',
#  '30-year',
#  '150-point',
#  '20-point',
#  '12-point',
#  '12-point',
#  '30-point',
#  '12-point',
#  '30-point',
#  '500-stock',
#  '10-day',
#  '30-day',
#  '30-day',
#  '30-day',
#  '10-day',
#  '30-day',
#  '30-day',
#  '10-day',
#  '90-day',
#  '15-day',
#  '10-day',
#  '100-share',
#  '84-month',
#  '21-month',
#  '30-year',
#  '240-page',
#  '30-year',
#  '190-point',
#  '30-year',
#  '100-share',
#  '30-share',
#  '30-year',
#  '30-year',
#  '30-year',
#  '10-year',
#  '30-year',
#  '30-year',
#  '30-year',
#  '10-year',
#  '12-year',
#  '10-year',
#  '500-stock',
#  '20-stock',
#  '36-store',
#  '27-year',
#  '87-store',
#  '42-year',
#  '237-seat',
#  '30-day',
#  '300-day']

# %%
[w for w in wsj if re.search('^[a-z]{5,}-[a-z]{2,3}-[a-z]{1,6}$',w)] # find number dash than a word
# Out:
# ['black-and-white',
#  'savings-and-loan',
#  'savings-and-loan',
#  'father-in-law',
#  'machine-gun-toting',
#  'bread-and-butter']

# %%
[w for w in wsj if re.search('(ed|ing)$',w)] # find number dash than a word
# Out:
# ['publishing',
#  'Consolidated',
#  'named',
#  'used',
#  'caused',
#  'exposed',
#  'reported',
#  'causing',
#  'York-based',
#  'stopped',
#  'using',
#  'reported',
#  'bring',
#  'talking',
#  'having',
#  'studied',
#  'led',
#  'used',
#  'making',
#  'replaced',
#  'worked',
#  'died',
#  'expected',
#  'surviving',
#  'asbestos-related',
#  'including',
#  'diagnosed',
#  'expected',
#  'striking',
#  'finding',
#  'asbestos-related',
#  'studied',
#  'industrialized',
#  'owned',
#  'finding',
#  'including',
#  'industrialized',
#  'classified',
#  'according',
#  'rejected',
#  'explained',
#  'imposed',
#  'remaining',
#  'cancer-causing',
#  'outlawed',
#  'exposed',
#  'used',
#  'dumped',
#  'imported',
#  'poured',
#  'mixed',
#  'used',
#  'described',
#  'ventilated',
#  'contracted',
#  'asbestos-related',
#  'bearing',
#  'continued',
#  'tracked',
#  'eased',
#  'ended',
#  'lengthened',
#  'according',
#  'declining',
#  'considered',
#  'rising',
# ...

# %%
# find all vovels in a word and count them
word = 'supercalifragilisticexpialidocious'
len(re.findall(r'[aeiou]',word))
# Out:
# 16

# %%
# sequences of two or more vovels and look at their relative frequency
wsj = sorted(set(nltk.corpus.treebank.words()))
fd = nltk.FreqDist(vs for word in wsj for vs in re.findall(r'[aeiou]{2,}',word))

# %%
fd.most_common(12)
# Out:
# [('io', 549),
#  ('ea', 476),
#  ('ie', 331),
#  ('ou', 329),
#  ('ai', 261),
#  ('ia', 253),
#  ('ee', 217),
#  ('oo', 174),
#  ('ua', 109),
#  ('au', 106),
#  ('ue', 105),
#  ('ui', 95)]

# %%
[int(n) for n in re.findall('[0-9]{2,4}', '2009-12-31')]
# Out:
# [2009, 12, 31]

# %%
def compress(word):
    regex = r'^[AEIOUaeiou]+|[AEIOUaeiou]+$|[^AEIOUaeiou]'
    pieces = re.findall(regex,word)
    return ''.join(pieces)
english_udhr = nltk.corpus.udhr.words('English-Latin1')
nltk.tokenwrap(compress(w) for w in english_udhr[:75])
# Out:
# 'Unvrsl Dclrtn of Hmn Rghts Prmble Whrs rcgntn of the inhrnt dgnty and\nof the eql and inlnble rghts of all mmbrs of the hmn fmly is the fndtn\nof frdm , jstce and pce in the wrld , Whrs dsrgrd and cntmpt fr hmn\nrghts hve rsltd in brbrs acts whch hve outrgd the cnscnce of mnknd ,\nand the advnt of a wrld in whch hmn bngs shll enjy frdm of spch and'

# %%
rotokas_words = nltk.corpus.toolbox.words('rotokas.dic')

# %%
#[cv for word in rotokas_words for cv in re.findall(r'[ptksvr][aeiou]',word)] # find words in rotokas corpora where there is a consonent folowed by a vovel

cfd = nltk.ConditionalFreqDist([consonent_vovel for word in rotokas_words  for consonent_vovel in re.findall(r'[ptksvr][aeiou]',word)])
# vovel is first condition and later the consonents
#[cv for word in rotokas_words for cv in re.findall(r'[ptksvr][aeiou]',word)]

# %%
cfd.conditions()
# Out:
# ['k', 'r', 'v', 's', 't', 'p']

# %%
cfd.tabulate()
# Out:
#     a   e   i   o   u
# k 418 148  94 420 173
# p  83  31 105  34  51
# r 187  63  84  89  79
# s   0   0 100   2   1
# t  47   8   0 148  37
# v  93  27 105  48  49

# %%
cfd.plot()

# %%
cv_word_pairs = [(cv,word) for word in rotokas_words  for cv in re.findall(r'[ptksvr][aeiou]',word)]

# %%
cv_index = nltk.Index(cv_word_pairs)

# %%
cv_index['su']
# Out:
# ['kasuari']

# %%
cv_index['po']
# Out:
# ['kaapo',
#  'kaapopato',
#  'kaipori',
#  'kaiporipie',
#  'kaiporivira',
#  'kapo',
#  'kapoa',
#  'kapokao',
#  'kapokapo',
#  'kapokapo',
#  'kapokapoa',
#  'kapokapoa',
#  'kapokapora',
#  'kapokapora',
#  'kapokaporo',
#  'kapokaporo',
#  'kapokari',
#  'kapokarito',
#  'kapokoa',
#  'kapoo',
#  'kapooto',
#  'kapoovira',
#  'kapopaa',
#  'kaporo',
#  'kaporo',
#  'kaporopa',
#  'kaporoto',
#  'kapoto',
#  'karokaropo',
#  'karopo',
#  'kepo',
#  'kepoi',
#  'keposi',
#  'kepoto']

# %%
words = nltk.corpus.brown.words(categories = 'news')
word = 'following'
for suffix in ['ing','ly','ed','ious','ies','ive','es','s','ment']:
    if word.endswith(suffix):
        word =  word[:-len(suffix)]
print(word)
# Out:
# follow

# %%
def stem(word):
    for suffix in ['ing','ly','ed','ious','ies','ive','es','s','ment','ion']:
        if word.endswith(suffix):
            word = word[:-len(suffix)]
    return word

# %%
[stem(word) for word in words ]
# Out:
# ['The',
#  'Fulton',
#  'County',
#  'Grand',
#  'Jury',
#  'said',
#  'Friday',
#  'an',
#  'investigat',
#  'of',
#  "Atlanta'",
#  'recent',
#  'primary',
#  'elect',
#  'produc',
#  '``',
#  'no',
#  'evidence',
#  "''",
#  'that',
#  'any',
#  'irregularit',
#  'took',
#  'place',
#  '.',
#  'The',
#  'jury',
#  'further',
#  'said',
#  'in',
#  'term-end',
#  'present',
#  'that',
#  'the',
#  'City',
#  'Execut',
#  'Committee',
#  ',',
#  'which',
#  'had',
#  'over-all',
#  'charge',
#  'of',
#  'the',
#  'elect',
#  ',',
#  '``',
#  'deserv',
#  'the',
#  'praise',
#  'and',
#  'thank',
#  'of',
#  'the',
#  'City',
#  'of',
#  'Atlanta',
#  "''",
#  'for',
#  'the',
#  'manner',
#  'in',
#  'which',
#  'the',
#  'elect',
#  'wa',
#  'conduct',
#  '.',
#  'The',
#  'September-October',
#  'term',
#  'jury',
#  'had',
#  'been',
#  'charg',
#  'by',
#  'Fulton',
#  'Superior',
#  'Court',
#  'Judge',
#  'Durwood',
#  'Pye',
#  'to',
#  'investigate',
#  'report',
#  'of',
# ...

# %%
re.findall('^.*(ing|ly|ed|ious|ies|ive|es|s|ment)$','processing')
# Out:
# ['ing']

# %%
re.findall('^.*(?:ing|ly|ed|ious|ies|ive|es|s|ment)$','processing')
# Out:
# ['processing']

# %%
re.findall('^.*(?:ing)$','processing')
# Out:
# ['processing']

# %%
re.findall('^(.*)(ing)$','preprocessing')
# Out:
# [('preprocess', 'ing')]

# %%
re.findall('^(.*)(ly)$','unknowingly')
# Out:
# [('unknowing', 'ly')]

# %%
re.findall('^(.*)(ing|ly|ed|ious|ies|ive|es|s|ment)$','preprocessing')
# Out:
# [('preprocess', 'ing')]

# %%
re.findall('^(.*)(ing|ly|ed|ious|ies|ive|es|s|ment)$','processes')
# Out:
# [('processe', 's')]

# %%
re.findall(r'^(.*?)(ing|ly|ed|ious|ies|ive|es|s|ment)$','processes')
# Out:
# [('process', 'es')]

# %%
re.findall(r'(.*?)(ing|ly|ed|ious|ies|ive|es|s|ment)$','processes')
# Out:
# [('process', 'es')]

# %%
re.findall(r'(.*?)(ing|ly|ed|ious|ies|ive|es|s|ment)$','language')
# Out:
# []

# %%
#function to perform stemming and applying to whole text
word = 'preprocessing'
regex = r'(.*?)(ing|ly|ed|ious|ies|ive|es|s|ment)?$'
stem,suffix = re.findall(regex,word)

# %%
stem,word = re.findall(regex,word)[0]

# %%
def stem(word):
    regex = r'(.*?)(ing|ly|ed|ious|ies|ive|es|s|ment)?$'
    stem,suffix = re.findall(regex,word)[0]
    return stem

# %%
raw = """DENNIS: Listen, strange women lying in ponds distributing swords
is no basis for a system of government.  Supreme executive power derives from
a mandate from the masses, not from some farcical aquatic ceremony."""
tokens = word_tokenize(raw)
[stem(w) for w in tokens]
# Out:
# ['DENNIS',
#  ':',
#  'Listen',
#  ',',
#  'strange',
#  'women',
#  'ly',
#  'in',
#  'pond',
#  'distribut',
#  'sword',
#  'i',
#  'no',
#  'basi',
#  'for',
#  'a',
#  'system',
#  'of',
#  'govern',
#  '.',
#  'Supreme',
#  'execut',
#  'power',
#  'deriv',
#  'from',
#  'a',
#  'mandate',
#  'from',
#  'the',
#  'mass',
#  ',',
#  'not',
#  'from',
#  'some',
#  'farcical',
#  'aquatic',
#  'ceremony',
#  '.']

# %%
from nltk.corpus import gutenberg,nps_chat
moby = nltk.Text(gutenberg.words('melville-moby_dick.txt'))
moby.findall(r"<a>(<.*>)<man>")
# Out:
# monied; nervous; dangerous; white; white; white; pious; queer; good;
# mature; white; Cape; great; wise; wise; butterless; white; fiendish;
# pale; furious; better; certain; complete; dismasted; younger; brave;
# brave; brave; brave

# %%
chat = nltk.Text(nps_chat.words())
chat.findall('<.*><.*><bro>')
# Out:
# you rule bro; telling you bro; u twizted bro

# %%
chat.findall('<l.*>{3,}')
# Out:
# lol lol lol; lmao lol lol; lol lol lol; la la la la la; la la la; la
# la la; lovely lol lol love; lol lol lol.; la la la; la la la

# %%
from nltk.corpus import brown
hobbies_learned = nltk.Text(brown.words(categories = ['hobbies','learned']))

# %%
hobbies_learned.findall(r'<\w*><and><other><\w*s>')
# Out:
# speed and other activities; water and other liquids; tomb and other
# landmarks; Statues and other monuments; pearls and other jewels;
# charts and other items; roads and other features; figures and other
# objects; military and other areas; demands and other factors;
# abstracts and other compilations; iron and other metals

# %%
raw = """DENNIS: Listen, strange women lying in ponds distributing swords
is no basis for a system of government.  Supreme executive power derives from
a mandate from the masses, not from some farcical aquatic ceremony."""
tokens = word_tokenize(raw)

# %%
porter = nltk.PorterStemmer()
lancaster = nltk.LancasterStemmer()
print([porter.stem(word) for word in tokens][:7])
print([lancaster.stem(word) for word in tokens])
# Out:
# ['denni', ':', 'listen', ',', 'strang', 'women', 'lie']
# ['den', ':', 'list', ',', 'strange', 'wom', 'lying', 'in', 'pond', 'distribut', 'sword', 'is', 'no', 'bas', 'for', 'a', 'system', 'of', 'govern', '.', 'suprem', 'execut', 'pow', 'der', 'from', 'a', 'mand', 'from', 'the', 'mass', ',', 'not', 'from', 'som', 'farc', 'aqu', 'ceremony', '.']

# %%
class IndexedText(object):

    def __init__(self, stemmer, text):
        self._text = text
        self._stemmer = stemmer
        self._index = nltk.Index((self._stem(word), i)
                                 for (i, word) in enumerate(text))

    def concordance(self, word, width=40):
        key = self._stem(word)
        wc = int(width/4)                # words of context
        for i in self._index[key]:
            lcontext = ' '.join(self._text[i-wc:i])
            rcontext = ' '.join(self._text[i:i+wc])
            ldisplay = '{:>{width}}'.format(lcontext[-width:], width=width)
            rdisplay = '{:{width}}'.format(rcontext[:width], width=width)
            print(ldisplay, rdisplay)

    def _stem(self, word):
        return self._stemmer.stem(word).lower()

# %%
porter = nltk.PorterStemmer()
grail = nltk.corpus.webtext.words('grail.txt')
text = IndexedText(porter,grail)

# %%
text.concordance('lie')
# Out:
# r king ! DENNIS : Listen , strange women lying in ponds distributing swords is no
#  beat a very brave retreat . ROBIN : All lies ! MINSTREL : [ singing ] Bravest of
#        Nay . Nay . Come . Come . You may lie here . Oh , but you are wounded !
# doctors immediately ! No , no , please ! Lie down . [ clap clap ] PIGLET : Well
# ere is much danger , for beyond the cave lies the Gorge of Eternal Peril , which
#    you . Oh ... TIM : To the north there lies a cave -- the cave of Caerbannog --
# h it and lived ! Bones of full fifty men lie strewn about its lair . So , brave k
# not stop our fight ' til each one of you lies dead , and the Holy Grail returns t

# %%
raw = """DENNIS: Listen, strange women lying in ponds distributing swords
is no basis for a system of government.  Supreme executive power derives from
a mandate from the masses, not from some farcical aquatic ceremony."""
tokens = word_tokenize(raw)

# %%
wnl = nltk.WordNetLemmatizer()
[wnl.lemmatize(t) for t in tokens]
# Out:
# ['DENNIS',
#  ':',
#  'Listen',
#  ',',
#  'strange',
#  'woman',
#  'lying',
#  'in',
#  'pond',
#  'distributing',
#  'sword',
#  'is',
#  'no',
#  'basis',
#  'for',
#  'a',
#  'system',
#  'of',
#  'government',
#  '.',
#  'Supreme',
#  'executive',
#  'power',
#  'derives',
#  'from',
#  'a',
#  'mandate',
#  'from',
#  'the',
#  'mass',
#  ',',
#  'not',
#  'from',
#  'some',
#  'farcical',
#  'aquatic',
#  'ceremony',
#  '.']

# %%
raw = """'When I'M a Duchess,' she said to herself, (not in a very hopeful tone
though), 'I won't have any pepper in my kitchen AT ALL. Soup does very
well without--Maybe it's always pepper that makes people hot-tempered,'..."""

# %%
re.split(r' ',raw)
# Out:
# ["'When",
#  "I'M",
#  'a',
#  "Duchess,'",
#  'she',
#  'said',
#  'to',
#  'herself,',
#  '(not',
#  'in',
#  'a',
#  'very',
#  'hopeful',
#  'tone\nthough),',
#  "'I",
#  "won't",
#  'have',
#  'any',
#  'pepper',
#  'in',
#  'my',
#  'kitchen',
#  'AT',
#  'ALL.',
#  'Soup',
#  'does',
#  'very\nwell',
#  'without--Maybe',
#  "it's",
#  'always',
#  'pepper',
#  'that',
#  'makes',
#  'people',
#  "hot-tempered,'..."]

# %%
re.split('[ \t\n]',raw)
# Out:
# ["'When",
#  "I'M",
#  'a',
#  "Duchess,'",
#  'she',
#  'said',
#  'to',
#  'herself,',
#  '(not',
#  'in',
#  'a',
#  'very',
#  'hopeful',
#  'tone',
#  'though),',
#  "'I",
#  "won't",
#  'have',
#  'any',
#  'pepper',
#  'in',
#  'my',
#  'kitchen',
#  'AT',
#  'ALL.',
#  'Soup',
#  'does',
#  'very',
#  'well',
#  'without--Maybe',
#  "it's",
#  'always',
#  'pepper',
#  'that',
#  'makes',
#  'people',
#  "hot-tempered,'..."]

# %%
re.split('\s+',raw)
# Out:
# ["'When",
#  "I'M",
#  'a',
#  "Duchess,'",
#  'she',
#  'said',
#  'to',
#  'herself,',
#  '(not',
#  'in',
#  'a',
#  'very',
#  'hopeful',
#  'tone',
#  'though),',
#  "'I",
#  "won't",
#  'have',
#  'any',
#  'pepper',
#  'in',
#  'my',
#  'kitchen',
#  'AT',
#  'ALL.',
#  'Soup',
#  'does',
#  'very',
#  'well',
#  'without--Maybe',
#  "it's",
#  'always',
#  'pepper',
#  'that',
#  'makes',
#  'people',
#  "hot-tempered,'..."]

# %%
re.split('\W+',raw)
# Out:
# ['',
#  'When',
#  'I',
#  'M',
#  'a',
#  'Duchess',
#  'she',
#  'said',
#  'to',
#  'herself',
#  'not',
#  'in',
#  'a',
#  'very',
#  'hopeful',
#  'tone',
#  'though',
#  'I',
#  'won',
#  't',
#  'have',
#  'any',
#  'pepper',
#  'in',
#  'my',
#  'kitchen',
#  'AT',
#  'ALL',
#  'Soup',
#  'does',
#  'very',
#  'well',
#  'without',
#  'Maybe',
#  'it',
#  's',
#  'always',
#  'pepper',
#  'that',
#  'makes',
#  'people',
#  'hot',
#  'tempered',
#  '']

# %%
'xx'.split('x')
# Out:
# ['', '', '']

# %%
re.findall(r'\W+',raw)
# Out:
# ["'",
#  ' ',
#  "'",
#  ' ',
#  ' ',
#  ",' ",
#  ' ',
#  ' ',
#  ' ',
#  ', (',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '\n',
#  "), '",
#  ' ',
#  "'",
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '. ',
#  ' ',
#  ' ',
#  '\n',
#  ' ',
#  '--',
#  ' ',
#  "'",
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '-',
#  ",'..."]

# %%
raw
# Out:
# "'When I'M a Duchess,' she said to herself, (not in a very hopeful tone\nthough), 'I won't have any pepper in my kitchen AT ALL. Soup does very\nwell without--Maybe it's always pepper that makes people hot-tempered,'..."

# %%
re.findall(r'\w+|\S\w*',raw)
# Out:
# ["'When",
#  'I',
#  "'M",
#  'a',
#  'Duchess',
#  ',',
#  "'",
#  'she',
#  'said',
#  'to',
#  'herself',
#  ',',
#  '(not',
#  'in',
#  'a',
#  'very',
#  'hopeful',
#  'tone',
#  'though',
#  ')',
#  ',',
#  "'I",
#  'won',
#  "'t",
#  'have',
#  'any',
#  'pepper',
#  'in',
#  'my',
#  'kitchen',
#  'AT',
#  'ALL',
#  '.',
#  'Soup',
#  'does',
#  'very',
#  'well',
#  'without',
#  '-',
#  '-Maybe',
#  'it',
#  "'s",
#  'always',
#  'pepper',
#  'that',
#  'makes',
#  'people',
#  'hot',
#  '-tempered',
#  ',',
#  "'",
#  '.',
#  '.',
#  '.']

# %%
re.findall("\w+(?:[-']\w+)*|'|[-.(]+|\S\w*",raw)
# Out:
# ["'",
#  'When',
#  "I'M",
#  'a',
#  'Duchess',
#  ',',
#  "'",
#  'she',
#  'said',
#  'to',
#  'herself',
#  ',',
#  '(',
#  'not',
#  'in',
#  'a',
#  'very',
#  'hopeful',
#  'tone',
#  'though',
#  ')',
#  ',',
#  "'",
#  'I',
#  "won't",
#  'have',
#  'any',
#  'pepper',
#  'in',
#  'my',
#  'kitchen',
#  'AT',
#  'ALL',
#  '.',
#  'Soup',
#  'does',
#  'very',
#  'well',
#  'without',
#  '--',
#  'Maybe',
#  "it's",
#  'always',
#  'pepper',
#  'that',
#  'makes',
#  'people',
#  'hot-tempered',
#  ',',
#  "'",
#  '...']

# %%
text = 'That U.S.A. poster-print costs $12.40...'

# %%
pattern = r'''(?x)(?:[A-Z]\.)+|\w+(?:-\w+)*|\$?\d+(?:\.\d+)?%?|\.\.\.|[][.,;"'?():-_`]'''
nltk.regexp_tokenize(text,pattern)
# Out:
# ['That', 'U.S.A.', 'poster-print', 'costs', '$12.40', '...']

# %%
# average number of words per sentences in brown corpus
len(nltk.corpus.brown.words())/len(nltk.corpus.brown.sents())
# Out:
# 20.250994070456922

# %%
text = nltk.corpus.gutenberg.raw('chesterton-thursday.txt')
sents = nltk.sent_tokenize(text)

# %%
sents[67:77]
# Out:
# ['The man with the meek blue eyes and the pale, pointed beard endured\nthese thunders with a certain submissive solemnity.',
#  "The third party\nof the group, Gregory's sister Rosamond, who had her brother's\nbraids of red hair, but a kindlier face underneath them, laughed\nwith such mixture of admiration and disapproval as she gave\ncommonly to the family oracle.",
#  'Gregory resumed in high oratorical good humour.',
#  '"An artist is identical with an anarchist," he cried.',
#  '"You might\ntranspose the words anywhere.',
#  'An anarchist is an artist.',
#  'The man\nwho throws a bomb is an artist, because he prefers a great moment\nto everything.',
#  'He sees how much more valuable is one burst of\nblazing light, one peal of perfect thunder, than the mere common\nbodies of a few shapeless policemen.',
#  'An artist disregards all\ngovernments, abolishes all conventions.',
#  'The poet delights in\ndisorder only.']

# %%
text = "doyouseethekittyseethedoggydoyoulikethekittylikethedoggy"
seg1 = "0000000000000001000000000010000000000000000100000000000"
seg2 = "0100100100100001001001000010100100010010000100010010000"

# %%
words = []
last = 0
for i in range(len(seg2)):
    if seg2[i] == '1':
        words.append(text[last:i+1]) # here we are using i+1 because during the counting of array the last element in the slice is ignored
        last = i+1 # we are going one element further
words.append(text[last:])

# %%
def segment(text,seg):
    words = []
    last = 0
    for i in range(len(seg)):
        if seg[i] == '1':
            words.append(text[last:i+1])
            last = i + 1
    words.append(text[last:])
    return words

def evaluate(text,seg):
    words = segment(text,seg)
    text_size = len(words)
    lexical_size = sum(len(word)+1 for word in set(words))
    return text_size + lexical_size

# %%
print(segment(text,seg1))
# Out:
# ['doyouseethekitty', 'seethedoggy', 'doyoulikethekitty', 'likethedoggy']

# %%
print(segment(text,seg2))
from random import randint
# Out:
# ['do', 'you', 'see', 'the', 'kitty', 'see', 'the', 'doggy', 'do', 'you', 'like', 'the', 'kitty', 'like', 'the', 'doggy']
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-129-5632dd7f3147> in <module>
#       1 print(segment(text,seg2))
# ----> 2 from ramdom import randint
#
# ModuleNotFoundError: No module named 'ramdom'

# %%
def evaluate(text,seg):
    words = segment(text,seg)
    text_size = len(words)
    lexical_size = sum(len(word)+1 for word in set(words))
    return text_size + lexical_size

# %%
evaluate(text,seg1)
# Out:
# 64

# %%
evaluate(text,seg2) # this score should always be minimum
# Out:
# 48

# %%
# now the next step is to find a function that minimizes this objective function score

# %%
def flip(segs,pos):
    return segs[:pos] + str(1 - int(segs[pos])) + segs[pos+1:]

# %%
def flip_n(segs,n):
    for i in range(n):
        segs = flip(segs,randint(0,len(segs)-1))
    return segs

# %%
def anneal(text,segs,iteration,cooling_rate):
    score_p = 0
    segs_p  = ''
    temperature = float(len(segs))
    while temperature > 0.5:
        best_score,best_segs = evaluate(segs,text),segs
        for i in range(iteration):
            guess = flip_n(segs,round(temperature))
            score = evaluate(text,guess)
            if score < best_score:
                best_score,best_segs = score,guess
        score,segs = best_score,best_segs
        temperature = temperature/cooling_rate
        print(evaluate(text,segs),'--->',segment(text,segs))

# %%
text = "doyouseethekittyseethedoggydoyoulikethekittylikethedoggy"
seg1 = "0000000000000001000000000010000000000000000100000000000"
anneal(text, seg1, 5000, 1.2)

# %%
def segment(text,seg):
    words = []
    last = 0
    for i in range(len(seg)):
        if seg[i] == '1':
            words.append(text[last:i+1])
            last = i + 1
    words.append(text[last:])
    return words

def evaluate(text,seg):
    words = segment(text,seg)
    text_size = len(words)
    lexical_size = sum(len(word)+1 for word in set(words))
    return text_size + lexical_size

def flip(segs,pos):
    return segs[:pos] + str(1 - int(segs[pos])) + segs[pos+1:]

def flip_n(segs,n):
    for i in range(n):
        segs = flip(segs,randint(0,len(segs)-1))
    return segs

def anneal(text,segs,iteration,cooling_rate):
    score_p = 0
    segs_p  = ''
    temperature = float(len(segs))
    while temperature > 0.5:
        best_score,best_segs = evaluate(segs,text),segs
        for i in range(iteration):
            guess = flip_n(segs,round(temperature))
            score = evaluate(text,guess)
            if score < best_score:
                best_score,best_segs = score,guess
        score,segs = best_score,best_segs
        temperature = temperature/cooling_rate
        print(evaluate(text,segs),'--->',segment(text,segs))

# %%
def segment(text,segs):
    words = []
    last = 0
    for i in range(len(segs)):
        if segs[i] == '1':
            words.append(text[last:i+1])
            last = i + 1
    words.append(text[last:])
    return words

# %%
def evaluate(text,segs):
    words = segment(text,segs)
    text_size = len(words)
    lexical_size = sum(len(word)+1 for word in set(words))
    return text_size + lexical_size

# %%
def flip(segs,pos):
    return segs[:pos] + str(1 - int(segs[pos])) + segs[pos+1:]
def flip_n(segs,n):
    for i in range(n):
        segs = flip(segs,randint(0,len(segs) - 1))
    return segs

# %%
def anneal(text,segs,iteration,cooling_rate):
    temperature = float(len(segs))
    while temperature > 0.5:
        best_segs,best_score = segs,evaluate(text,segs)
        for i in range(iteration):
            guess = flip_n(segs,round(temperature))
            score = evaluate(text,guess)
            if score < best_score:
                best_segs,best_score = guess,score
        score,segs = best_score,best_segs
        temperature = temperature / cooling_rate
        print(evaluate(text,segs),segment(text,segs))

# %%
text = "doyouseethekittyseethedoggydoyoulikethekittylikethedoggy"
seg1 = "0000000000000001000000000010000000000000000100000000000"
anneal(text, seg1, 5000, 1.2)

# %%
text = "doyouseethekittyseethedoggydoyoulikethekittylikethedoggy"
seg1 = "0000000000000001000000000010000000000000000100000000000"
seg2 = "0100100100100001001001000010100100010010000100010010000"
seg3 = "0000100100000011001000000110000100010000001100010000001"

# %%
silly = ['We','called','him','Tortoise','because','he','taught','us','.']
' '.join(silly)

# %%
';'.join(silly)

# %%
''.join(silly)

# %%
word = 'cat'
sentence = """hello
... world"""

# %%
print(word)

# %%
print(sentence)

# %%
word

# %%
sentence

# %%
fdist = nltk.FreqDist(['dog','cat','dog','cat','dog','snake','dog','cat'])
for word in sorted(fdist):
    print(word,'->',fdist[word])

# %%
for word in sorted(fdist):
    print("{}-->{}".format(word,fdist[word]))

# %%
'{}-->{}'.format('cat',3)

# %%
'{}-->'.format('cat')

# %%
'{}'.format(3)

# %%
'I want a {} right now'.format('coffee')

# %%
'{} wants a {} for {}'.format('Lee','sandwich','lunch')

# %%
'from {0} to {1}'.format('A','B')

# %%
template = 'Lee wants a {} right now'
menu = ['sandwich','spam fitter','pancake']
for val in menu:
    print(template.format(val))

# %%
'{:6}'.format(41) # numbers are right justified

# %%
'{:<6}'.format(41) # we can make it left justified by adding a <

# %%
'{:6}'.format('dog') # strings are left justified by default

# %%
'{:>6}'.format('dog') # we can make it right justified by adding a >

# %%
import math
'{:.4f}'.format(math.pi)

# %%
count,total = 3250,9375
'accuracy for {} words = {:.4f}'.format(total,count/total)

# %%
from nltk.corpus import brown
cfd = nltk.ConditionalFreqDist(
    (genre,word)
    for genre in brown.categories()
    for word in brown.words(categories = genre)
)
genres = ['news','religion','hobbies','science_fiction','romance','humor']
modals = ['can','could','may','might','must','will']

# %%
cfd.tabulate(samples = modals,conditions =genres)

# %%
#cfd modals genres
print('{:16}'.format('Category'),end = ' ')
for word in modals:
    print('{:>6}'.format(word),end = ' ')
print()
for genre in genres:
    print('{:16}'.format(genre) , end = '')
    for word in modals:
        print('{:6}'.format(cfd[genre][word]),end = ' ')
    print()

# %%
saying = ['After', 'all', 'is', 'said', 'and', 'done', ',','more', 'is', 'said', 'than', 'done', '.']
for word in saying:
    print(word, '(' + str(len(word)) + ')',end =' ')

# %%
from textwrap import fill
pieces = ["{} {}".format(word,len(word)) for word in saying]

# %%
fill(' '.join(pieces))
